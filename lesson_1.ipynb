# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.shape
# Out:
# (73268, 78)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MainBranch                      73268 non-null  object
#  1   Employment                      71709 non-null  object
#  2   RemoteWork                      58958 non-null  object
#  3   CodingActivities                58899 non-null  object
#  4   EdLevel                         71571 non-null  object
#  5   LearnCode                       71580 non-null  object
#  6   LearnCodeOnline                 50685 non-null  object
#  7   LearnCodeCoursesCert            29389 non-null  object
#  8   YearsCode                       71331 non-null  object
#  9   YearsCodePro                    51833 non-null  object
#  10  DevType                         61302 non-null  object
#  11  OrgSize                         51039 non-null  object
# ...

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 9                              I am a developer by profession
# 10                             I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %%
df.tail(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 73259                          I am a developer by profession
# 73260                          I am a developer by profession
# 73261                          I am a developer by profession
# 73262                          I am a developer by profession
# 73263                                   I am learning to code
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 73259                                     Employed, full-time
# 73260                                     Employed, full-time
# 73261                  Employed, full-time;Student, part-time
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
schema_df.loc['YearsCode', 'question']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
schema_df.sort_index(ascending=False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# VersionControlSystem  QID283
# VCInteraction         QID284
# VCHosting             QID285
# TrueFalse_3           QID294
# TrueFalse_2           QID294
# TrueFalse_1           QID294
# TrueFalse             QID294
# Trans                 QID153
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# Sexuality             QID136
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# S7                    QID131
# S6                    QID295
# S5                    QID121
# S4                     QID91
# S3                     QID61
# S2                    QID190
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# Accessibility         QID124
# Age                   QID127
# Blockchain            QID305
# BuyNewTool            QID279
# CodingActivities      QID297
# CompFreq               QID52
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Ethnicity             QID126
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Gender                QID122
# ICorPM                QID287
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Language              QID233
# LearnCode             QID276
# ...

# %%
# high_salery = (df['CompTotal'] > 700000)
# countries = ['Poland', 'Taiwan', 'Norway']
# filt = df['Country'].isin(countries)
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
# df.loc[filt, ['Country', 'LanguageHaveWorkedWith', 'CompTotal']]
# Out:
#            Country                             LanguageHaveWorkedWith  \
# ResponseId
# 35          Poland          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 47          Norway                   Bash/Shell;C;C++;Java;Lua;Python
# 52          Poland  Bash/Shell;HTML/CSS;Java;JavaScript;Python;Rus...
# 55          Norway  Bash/Shell;C#;HTML/CSS;Java;JavaScript;LISP;Po...
# 57          Taiwan                                                C++
# ...            ...                                                ...
# 73129       Poland  Bash/Shell;C++;HTML/CSS;Java;JavaScript;Lua;PH...
# 73147       Poland                       Bash/Shell;Elixir;JavaScript
# 73168       Norway                       JavaScript;Kotlin;TypeScript
# 73218       Poland        C#;HTML/CSS;JavaScript;Julia;SQL;TypeScript
# 73260       Poland                                             Elixir
#
#             CompTotal
# ResponseId
# 35            30000.0
# 47                NaN
# 52            14000.0
# ...

# %%
df.loc[filt, ['LanguageHaveWorkedWith']]
# Out:
#                                        LanguageHaveWorkedWith
# ResponseId
# 3                           C#;C++;HTML/CSS;JavaScript;Python
# 7               C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15                HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                       C#;Java;PHP;Python;R
# ...                                                       ...
# 73258                                            C;Python;SQL
# 73262       Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73264       Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265               Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                      HTML/CSS;JavaScript;PHP;Python;SQL
#
# [34155 rows x 1 columns]

# %%
filt
# Out:
# ResponseId
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 73264     True
# 73265     True
# 73266     True
# 73267    False
# 73268    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool
